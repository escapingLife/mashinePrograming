# %% [markdown]
# <a href="https://colab.research.google.com/github/escapingLife/mashinePrograming/blob/master/9%EC%A3%BC%EC%B0%A8/Alcohol_Sales_window_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ------------------------------------
# 1. 데이터 로드
# ------------------------------------
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Alcohol_Sales.csv')
data = df['S4248SM144NCEN'].values.reshape(-1, 1)

# %%
# ------------------------------------
# 2. 정규화
# ------------------------------------
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
# ------------------------------------
# 3. 시퀀스 생성 (window=6)
# ------------------------------------
window = 6
X, y = [], []
for i in range(len(data) - window):
    X.append(data[i:i+window])
    y.append(data[i+window])
X, y = np.array(X), np.array(y)

# %%
# ------------------------------------
# 4. Train/Test 분할 (8:2, 시계열이므로 shuffle X)
# ------------------------------------
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# ------------------------------------
# 5. 첫 번째 모델 (RNN)
# ------------------------------------
model_rnn = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(64, activation='tanh', input_shape=(window, 1)),
    tf.keras.layers.Dense(1)
])
model_rnn.compile(optimizer='adam', loss='mse')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# ------------------------------------
# 6. 두 번째 모델 (LSTM)
# ------------------------------------
model_lstm = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, activation='tanh', return_sequences=True, input_shape=(window, 1)),
    tf.keras.layers.LSTM(32, activation='tanh'),
    tf.keras.layers.Dense(1)
])
model_lstm.compile(optimizer='adam', loss='mse')

# %%
# ------------------------------------
# 7. 모델 학습
# ------------------------------------
history_rnn = model_rnn.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=8,
    verbose=1
)

history_lstm = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=8,
    verbose=1
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0194 - val_loss: 0.0240
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 0.0187
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - val_loss: 0.0139
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0136
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048 - val_loss: 0.0134
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048 - val_loss: 0.0132
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051 - val_loss: 0.0135
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0153
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056 - val_loss: 0.0132
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0147
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - val_loss: 0.0131
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - val_loss: 0.0131
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - val_loss: 0.0182
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - val_loss: 0.0141
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - val_loss: 0.0138
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - val_loss: 0.0132
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0144
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0133
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0130
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - val_loss: 0.0131
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0145
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0132
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - val_loss: 0.0154
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - val_loss: 0.0130
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - val_loss: 0.0135
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - val_loss: 0.0136
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - val_loss: 0.0145
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - val_loss: 0.0174
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - val_loss: 0.0165
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 0.0146
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 0.0132
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0146
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0130
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - val_loss: 0.0138
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - val_loss: 0.0130
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 0.0140
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0132
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0135
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 0.0143
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0135
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - val_loss: 0.0160
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - val_loss: 0.0149
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0145
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - val_loss: 0.0132
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - val_loss: 0.0131
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0131
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - val_loss: 0.0159
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0130
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0138
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0383 - val_loss: 0.0408
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0069 - val_loss: 0.0175
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0057 - val_loss: 0.0152
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0067 - val_loss: 0.0152
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0061 - val_loss: 0.0175
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0066 - val_loss: 0.0160
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0049 - val_loss: 0.0231
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0072 - val_loss: 0.0155
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0059 - val_loss: 0.0149
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053 - val_loss: 0.0158
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - val_loss: 0.0149
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - val_loss: 0.0149
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - val_loss: 0.0157
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.0175
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062 - val_loss: 0.0175
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - val_loss: 0.0150
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0181
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0057 - val_loss: 0.0164
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053 - val_loss: 0.0165
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - val_loss: 0.0153
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0156
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0166
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - val_loss: 0.0149
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066 - val_loss: 0.0147
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - val_loss: 0.0154
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - val_loss: 0.0193
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - val_loss: 0.0150
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - val_loss: 0.0151
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - val_loss: 0.0149
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056 - val_loss: 0.0148
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - val_loss: 0.0156
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - val_loss: 0.0154
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053 - val_loss: 0.0169
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0054 - val_loss: 0.0149
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - val_loss: 0.0169
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - val_loss: 0.0147
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - val_loss: 0.0158
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053 - val_loss: 0.0155
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0056 - val_loss: 0.0149
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0062 - val_loss: 0.0208
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0064 - val_loss: 0.0153
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0059 - val_loss: 0.0171
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0053 - val_loss: 0.0147
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0057 - val_loss: 0.0167
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0061 - val_loss: 0.0156
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0050 - val_loss: 0.0146
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0056 - val_loss: 0.0147
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051 - val_loss: 0.0147
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - val_loss: 0.0173
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051 - val_loss: 0.0149

# %%
# ------------------------------------
# 8. 테스트 데이터로 예측 (훈련 데이터 사용 X)
# ------------------------------------
pred_rnn = model_rnn.predict(X_test)
pred_lstm = model_lstm.predict(X_test)

# 앙상블: 평균
final_pred = (pred_rnn + pred_lstm) / 2
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
# ------------------------------------
# 9. MSE 시각화
# ------------------------------------
plt.figure(figsize=(8,4))
plt.plot(history_rnn.history['val_loss'], label='RNN Test MSE', alpha=0.7)
plt.plot(history_lstm.history['val_loss'], label='LSTM Test MSE', alpha=0.7)
plt.title('Validation MSE (RNN vs LSTM)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()

# %%
# ------------------------------------
# 10. 실제값 vs 예측값 시각화
# ------------------------------------
true_vals = scaler.inverse_transform(y_test)
pred_avg = scaler.inverse_transform(final_pred)

plt.figure(figsize=(10,5))
plt.plot(true_vals, label='True', color='black')
plt.plot(pred_avg, label='RNN-LSTM Ensemble Pred', color='red')
plt.title('RNN + LSTM Ensemble Prediction')
plt.legend()
plt.show()
