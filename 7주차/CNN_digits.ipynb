# %% [markdown]
# <a href="https://colab.research.google.com/github/escapingLife/mashinePrograming/blob/master/7%EC%A3%BC%EC%B0%A8/CNN_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

# 1. 데이터 불러오기
digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
# 1. 데이터 불러오기
digits = datasets.load_digits()
X = digits.images  # (1797, 8, 8)
y = digits.target

# %%
# 2. 데이터 차원 변환 (CNN 입력 형식: (샘플, 높이, 너비, 채널))
X = X.reshape(-1, 8, 8, 1)

# %%
# 3. 정규화 (0~1)
X = X / 16.0  # digits 데이터는 원래 픽셀 값이 0~16 범위

# %%
# 4. One-hot 인코딩
y_categorical = to_categorical(y, num_classes=10)

# %%
# 5. 학습/테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.3, random_state=42
)

# %%
# 6. CNN 모델 정의
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(8,8,1), padding='same'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')  # 0~9 숫자 분류
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 7. 모델 컴파일
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # 분류 문제에서는 mse 대신 crossentropy
    metrics=['accuracy']
)

# %%
# 8. 학습
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.1233 - loss: 2.2881 - val_accuracy: 0.3574 - val_loss: 2.1603
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2658 - loss: 2.1460 - val_accuracy: 0.7778 - val_loss: 1.7258
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4334 - loss: 1.7432 - val_accuracy: 0.8407 - val_loss: 1.0706
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5962 - loss: 1.2768 - val_accuracy: 0.9019 - val_loss: 0.6458
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7080 - loss: 0.9185 - val_accuracy: 0.8944 - val_loss: 0.4206
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7365 - loss: 0.8006 - val_accuracy: 0.9259 - val_loss: 0.3435
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8132 - loss: 0.5724 - val_accuracy: 0.9370 - val_loss: 0.2595
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8459 - loss: 0.5210 - val_accuracy: 0.9481 - val_loss: 0.2177
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8551 - loss: 0.4582 - val_accuracy: 0.9444 - val_loss: 0.1753
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8729 - loss: 0.4372 - val_accuracy: 0.9667 - val_loss: 0.1435
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8776 - loss: 0.3572 - val_accuracy: 0.9611 - val_loss: 0.1411
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9072 - loss: 0.3224 - val_accuracy: 0.9537 - val_loss: 0.1353
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9106 - loss: 0.3105 - val_accuracy: 0.9704 - val_loss: 0.1097
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9119 - loss: 0.2787 - val_accuracy: 0.9759 - val_loss: 0.0846
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9286 - loss: 0.2326 - val_accuracy: 0.9778 - val_loss: 0.0787
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9396 - loss: 0.2086 - val_accuracy: 0.9778 - val_loss: 0.0743
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9251 - loss: 0.2372 - val_accuracy: 0.9833 - val_loss: 0.0627
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.2500 - val_accuracy: 0.9796 - val_loss: 0.0688
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9346 - loss: 0.2045 - val_accuracy: 0.9833 - val_loss: 0.0659
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9449 - loss: 0.1728 - val_accuracy: 0.9815 - val_loss: 0.0658
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9429 - loss: 0.2032 - val_accuracy: 0.9852 - val_loss: 0.0598
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9537 - loss: 0.1483 - val_accuracy: 0.9852 - val_loss: 0.0531
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9620 - loss: 0.1359 - val_accuracy: 0.9852 - val_loss: 0.0555
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9466 - loss: 0.1631 - val_accuracy: 0.9889 - val_loss: 0.0577
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9525 - loss: 0.1491 - val_accuracy: 0.9870 - val_loss: 0.0474
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9583 - loss: 0.1355 - val_accuracy: 0.9870 - val_loss: 0.0578
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9559 - loss: 0.1292 - val_accuracy: 0.9889 - val_loss: 0.0388
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9709 - loss: 0.1072 - val_accuracy: 0.9889 - val_loss: 0.0400
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9555 - loss: 0.1260 - val_accuracy: 0.9889 - val_loss: 0.0371
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9722 - loss: 0.0958 - val_accuracy: 0.9907 - val_loss: 0.0362

# %%
# 9. 평가
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"CNN 모델 테스트 정확도: {acc:.4f}")
# Out:
# CNN 모델 테스트 정확도: 0.9907

# %%
# 10. 학습 곡선 시각화
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training/Validation Accuracy")

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train_loss (CrossEntropy)')
plt.plot(history.history['val_loss'], label='val_loss (CrossEntropy)')
plt.xlabel("Epoch")
plt.ylabel("Loss (CrossEntropy)")
plt.legend()
plt.title("Training/Validation Loss (CrossEntropy)")

plt.show()
